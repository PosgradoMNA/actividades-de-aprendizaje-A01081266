# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01081266/blob/main/A01081266_Notbooks_del_m%C3%B3dulo_1_(Data_Analysis_with_Python%2C_IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Analysus with Python module 1
#
# Introducción
#
#
# > aprender  acerca de estimacion del precio de carros (1985)
#
#
# > ver los paquetes de análisls de datos
#
# > se puede estimar el precio de un carro basandose en sus caracteristicas?

# %% [markdown]
# El problema
#
# datos estan en todos lados
# el análisis de datos es importante para descubrir informacion que nos puede ayudar a resolver problemas (como estimar el precio de un carro usado)

# %% [markdown]
# Entendiendo el problema
#
# obtener datos que nos ayuden a estimar el precio, usualmente son Datasets con atributos que son caracteristicas que determinan el precio

# %% [markdown]
# Paquetes para data science de Python
#
# Libreria: coleccion de funciones y métodos para usarse sin necesidad de escribir código
#
# Scientific computer libraries
#
#
# > Pandas: permite manilar y analisar datos, da acceso a datos estructurados
#
#
# > Numpy: usa arreglos y objetos, para procesarlos eficiente y rápidamente
#
#
# > scipy: funciones para problemas matematicos avanzados (como integrales, derivadas y demas)
#
#
# Librerias de visualización
#
#
# > Matplotlib: plots y gráficas personalizables
# >Seaborn: plots faciles de generar, mapas de calor, series de tiempo y diagramas de violin
#
# Algoritmicas
# > Scikit learn: herramientas para machine learning como regresion y clasificación
# > permite explorar datos, modelos y pruebas estadisticas.

# %% [markdown]
# Importar y exportar datos
#
# * adquisición de datos, importarlos y leerlos se puede hacer con Pandas
#
# * hay que tener el formato y el path donde se encuentran los datos.
#
# 1- definir la variable con el path
# 2-usar el metodo read_csv para obtener los datos
# 3- se puede usar dataframe.head para mostrar las primeras n filas o .tail para mostrar las n filas del final
#
# Headers=[" poner los nombres de las columnas separados por comas"]
#
# to_csv path #se usa para guardar un nuevo CSV en el path indicado

# %% [markdown]
# Getting Started
#
# es importante revisar el tipo de datos para evitar errores de wrong data types
#
# df.dtypes
#
# las metricas estadisticas pueden mostrar problemas matemáticos, como outliers y desviaciones importantes
#
# df.describe nos puede ayudar datos importantes, pero se brinca las columnas que no tengan datos numericos
#
# si ponemos el parámetro (include="all") ya nos mostrará la información de todas las columnas
#
# NaN es Not a Number

# %%
print(df.columns) #shows the name of the columns

dataframe.describe() #This method will provide various summary statistics, excluding NaN (Not a Number) values

# %% [markdown]
# ![image.png](data:image/png;base64,...)
